# %%
#Importing Required Libraries

import pytesseract
from PIL import Image, ImageEnhance, ImageFile
import cv2
import numpy as np
import math
from scipy import ndimage
import os
import re
import glob
import datetime
import pandas as pd

# %%
# Setting paths for PyTesseract and processing folders

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
rec_path = "C:/Users/mohan/Desktop/Project Image/20191217/Received/"
inp_path = "C:/Users/mohan/Desktop/Project Image/20191217/Input/"
prs_path = "C:/Users/mohan/Desktop/Project Image/20191217/Process/"
wrk_path = "C:/Users/mohan/Desktop/Project Image/20191217/Working/"
out_path = "C:/Users/mohan/Desktop/Project Image/20191217/Output/"
rst_path = "C:/Users/mohan/Desktop/Project Image/20191217/Result/"
tmp_path = "C:/Users/mohan/Desktop/Project Image/20191217/Templates/"

# %%
# Reading file and append list of file name
print (datetime.datetime.utcnow()) 
filename = []
directory = os.fsencode(out_path)
for file in os.listdir(directory):
    filename.append (os.fsdecode(file))
# Out:
# 2020-01-18 17:37:35.489685

# %%
# Reading file and append list of "Amount in words"

Amount1 = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Amount1: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                amt1 = match.group(1)
                
                Amount1.append(amt1) 
                
#print(Amount1)

# %%
date = []
for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Date1: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                date1 = match.group(1)
                
                date.append(date1)
                
                #print(date)

# %%
# Reading file and append list of "Date"

date = []
for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Date1: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                date1 = match.group(1)
                
                date.append(date1)
                
# Reading file and append list of "Sponsor Bank Code"

Sponsor_Bank_Code = []
for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Sponsor Bank Code: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                SBC = match.group(1)
                
                Sponsor_Bank_Code.append(SBC)
                

# Reading file and append list of "Utility Code"

Utility_Code = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Utility Code: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                UC = match.group(1)
                
                Utility_Code.append(UC)

# Reading file and append list of "Authorised Party"

Authorised = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Authorised Party: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                auth = match.group(1)
                
                Authorised.append(auth)
                
# Reading file and append list of "Bank Name"

Bank_Name = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Bank Name: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                bn = match.group(1)
                
                Bank_Name.append(bn)
                

# Reading file and append list of "Bank A/c No"

Bank_Ac_no = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Bank A/c No: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                ba = match.group(1)
                
                Bank_Ac_no.append(ba)
                
# Reading file and append list of "IFSC Code"

IFSC_code = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'IFSC Code: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                ifsc = match.group(1)
                
                IFSC_code.append(ifsc)

# Reading file and append list of "Amount in words"

Amount1 = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Amount1: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                amt1 = match.group(1)
                
                Amount1.append(amt1) 

# Reading file and append list of "Amount"

Amount = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Amount: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                amt = match.group(1)
                
                Amount.append(amt)
                
                
# Reading file and append list of "Reference 1"

Ref_1 = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Reference 1: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                rf1 = match.group(1)
                
                Ref_1.append(rf1)  
                
                
# Reading file and append list of "Reference 2"

Ref_2 = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Reference 2: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                rf2 = match.group(1)
                
                Ref_2.append(rf2)
                

# Reading file and append list of "Mobile Number"

Mobile = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'Mobile Number: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                Mob = match.group(1)
                
                Mobile.append(Mob) 
                
                
# Reading file and append list of "email id"

email = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'email id: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                eml = match.group(1)
                
                email.append(eml) 
                
# Reading file and append list of "from date"

from_date = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'From Date: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                frmd = match.group(1)
                
                from_date.append(frmd)
                

# Reading file and append list of "To Date"

To_date = []

for file in filename:
    with open(out_path + file) as fd:
        # Iterate over the lines
        for line in fd:
            
            # Capture one-or-more characters of non-whitespace after the initial match
            match = re.search(r'To Date: (.*$)', line,  re.IGNORECASE)
            
            # Did we find a match?
            if match:
                # Yes, process it
                tod = match.group(1)
                
                To_date.append(tod)

# %% [markdown]
# print(Amount1)

# %%
# Creating a data frame out of lists with Column Names

df = pd.DataFrame(list(zip(filename, date, Sponsor_Bank_Code, Utility_Code, Authorised, Bank_Name, Bank_Ac_no, IFSC_code, Amount1, Amount, Ref_1, Ref_2, Mobile, email, from_date, To_date)), 
               columns =['File Name', 'Date', 'Sponsor Bank Code', 'Utility Code', 'Authorised Party', 'Bank Name', 'Bank Ac No', 'IFSC code', 'Amount (words)', 'Amount', 'Reference 1', 'Reference 2', 'Mobile No', 'Email ID', 'From Date', 'To Date'])

# %% [markdown]
# print(df)

# %%
# Writing the dataframe to excel file
df.to_excel(rst_path + "output.xlsx")

print (datetime.datetime.utcnow())
# Out:
# 2020-01-18 17:37:40.233761
